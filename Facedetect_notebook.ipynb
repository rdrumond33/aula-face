# %%
import cv2
import os
from matplotlib import pyplot as plt

# %%
def save_face(face, name_file):
    print("Salvando Frame Face: {}".format(name_file))
    cv2.imwrite(name_file + '.png', face)

# %%
def histograma_face(frame_face, name_file):
    plt.clf()
    print("Salvando Histograma da face: {}".format(name_file)+".jpg")
    plt.hist(frame_face.ravel(),256,[0,256])
    plt.savefig(name_file+".jpg")
    plt.plot()

# %%
def histograma_vide(frame, name_file):
    plt.cla()
    print("Salvando Histograma do frame do Video: {}".format(name_file)+".jpg")
    plt.hist(frame.ravel(),256,[0,256])
    plt.savefig(name_file+".jpg")
    plt.plot()

# %%
def read_video(file_video):
    plt.rcParams['figure.figsize'] = (224, 224)
    face_cascade = cv2.CascadeClassifier(
        'modelo/haarcascade_frontalface_default.xml')
    name_file_face = "Pessoas/face{}"

    if not os.path.exists("Hist"):
        os.makedirs("Hist")
    if not os.path.exists("HistFace"):
        os.makedirs("HistFace")
    if not os.path.exists("Pessoas"):
        os.makedirs("Pessoas")

    cap = cv2.VideoCapture(file_video)
    i, j = 0, 0
    print("Comecando lendo o video: {}".format(file_video))
    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret == True:
            histograma_vide(frame, "Hist/histogramaVideo{}".format(i))
            i += 1
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

            faces = face_cascade.detectMultiScale(
                gray,
                scaleFactor=1.1,
                minNeighbors=5,
                minSize=(30, 30),
            )

            for (x, y, w, h) in faces:
                frame = cv2.rectangle(
                    frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
                roi_gray = gray[y:y+h, x:x+w]
                roi_color = frame[y:y+h, x:x+w]
                save_face(roi_color, name_file_face.format(j))
                histograma_face(
                    roi_color, "HistFace/histograma_face{}".format(j))

                j += 1
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        else:
            break

    cap.release()
    cv2.destroyAllWindows()
    print('Acabou')

# %%
read_video('faces.mp4')
# Out:
# Comecando lendo o video: faces.mp4
# Salvando Histograma do frame do Video: Hist/histogramaVideo0.jpg
# Salvando Frame Face: Pessoas/face0
# Salvando Histograma da face: HistFace/histograma_face0.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-be180ca55f09> in <module>
# ----> 1 read_video('faces.mp4')
#
# <ipython-input-5-8e4e2de2f87e> in read_video(file_video)
#      36                 save_face(roi_color, name_file_face.format(j))
#      37                 histograma_face(
# ---> 38                     roi_color, "HistFace/histograma_face{}".format(j))
#      39
#      40                 j += 1
#
# <ipython-input-3-9c7a77549c36> in histograma_face(frame_face, name_file)
#       3     print("Salvando Histograma da face: {}".format(name_file)+".jpg")
#       4     plt.hist(frame_face.ravel(),256,[0,256])
# ----> 5     plt.savefig(name_file+".jpg")
#       6     plt.plot()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_jpg(self, filename_or_obj, dryrun, pil_kwargs, *args, **kwargs)
#     595             pil_kwargs.setdefault("dpi", (self.figure.dpi, self.figure.dpi))
#     596             return background.save(
# --> 597                 filename_or_obj, format='jpeg', **pil_kwargs)
#     598
#     599         print_jpeg = print_jpg
#
# ~/anaconda3/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2086
#    2087         try:
# -> 2088             save_handler(self, fp, filename)
#    2089         finally:
#    2090             # do what we can to clean up
#
# ~/anaconda3/lib/python3.7/site-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
#     777     bufsize = max(ImageFile.MAXBLOCK, bufsize, len(exif) + 5, len(extra) + 1)
#     778
# --> 779     ImageFile._save(im, fp, [("jpeg", (0, 0) + im.size, 0, rawmode)], bufsize)
#     780
#     781
#
# ~/anaconda3/lib/python3.7/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     528                 l, s = e.encode_to_pyfd()
#     529             else:
# --> 530                 s = e.encode_to_file(fh, bufsize)
#     531             if s < 0:
#     532                 raise IOError("encoder error %d when writing image file" % s)
#
# KeyboardInterrupt:
